# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahneesh/cbg-predictive-analytics/blob/main/CBG___Try_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports

import pandas as pd
import numpy as np

# Visualisation libraries
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns

# Preprocessing libraries
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
input_data=pd.read_excel('/content/drive/MyDrive/Entri - Data Science with Gen AI - Assignments/#3: Main Project/CBG _ real Data.xlsx')
display(input_data.head())
display(input_data.describe())
# Out:
#    Serial Number       Date  Feed TPD - PS  PS - TS %  PS - VS %  \
# 0              1 2035-01-01           30.6       88.4       83.7
# 1              2 2035-01-02           13.5       89.5       85.0
# 2              3 2035-01-03           65.4       81.3       72.6
# 3              4 2035-01-04           23.5       85.9       76.3
# 4              5 2035-01-05           22.3       76.3       70.4
#
#    Feed TPD - PMC  PMC - TS %  PMC - VS %  Feed TPD - CD  CD - TS %  ...  \
# 0            30.6        88.4        83.7             36       30.8  ...
# 1            13.5        89.5        85.0             40       38.8  ...
# 2            65.4        81.3        72.6             43       39.9  ...
# 3            23.5        85.9        76.3             21       36.5  ...
# 4            22.3        76.3        70.4              0       36.5  ...
#
#    Rolling_Avg_VS_7D  Hydrolyser Temp - Avg  Digester Temp - Avg   HRT  \
# 0                NaN                    NaN                  NaN  1.81
# 1                NaN                    NaN                  NaN  2.81
# 2                NaN                    NaN                  NaN  3.70
# 3                NaN                    NaN                  NaN  1.96
# 4                NaN                    NaN                  NaN  2.30
#
#        VFA   OLR  Raw biogas production (Nm³/day)  \
# 0  10552.1  37.0                          18967.0
# 1  10350.8  21.0                          20608.0
# 2   9560.4  19.0                          20395.0
# 3  14206.2  32.0                          21721.0
# 4   9078.0  25.0                          21032.0
#
#    Slurry fed into the digester (Nm3)  Slurry fed out of the digester (Nm3)  \
# 0                               760.0                                 513.0
# 1                               810.0                                 730.0
# 2                               885.0                                 622.0
# 3                               890.0                                 512.0
# 4                               741.0                                 692.0
#
#    CBG Production (kg/day)
# 0                    6.169
# 1                    6.889
# 2                    6.907
# 3                    6.808
# 4                    7.164
#
# [5 rows x 27 columns]
#        Serial Number                 Date  Feed TPD - PS   PS - TS %  \
# count     646.000000                  646     646.000000  646.000000
# mean      323.500000  2035-11-19 12:00:00      66.536687   86.837910
# min         1.000000  2035-01-01 00:00:00       0.000000    0.000000
# 25%       162.250000  2035-06-11 06:00:00      30.000000   87.160000
# 50%       323.500000  2035-11-19 12:00:00      67.650000   89.505000
# 75%       484.750000  2036-04-28 18:00:00     100.400000   91.407500
# max       646.000000  2036-10-07 00:00:00     140.600000   98.000000
# std       186.628419                  NaN      40.079563   11.495255
#
#         PS - VS %  Feed TPD - PMC  PMC - TS %  PMC - VS %  Feed TPD - CD  \
# count  646.000000      646.000000  646.000000  646.000000     646.000000
# mean    80.426146       66.536687   86.837910   80.426146      28.407121
# min      0.000000        0.000000    0.000000    0.000000       0.000000
# 25%     79.380000       30.000000   87.160000   79.380000      10.000000
# 50%     81.310000       67.650000   89.505000   81.310000      25.000000
# 75%     83.190000      100.400000   91.407500   83.190000      40.000000
# max     87.920000      140.600000   98.000000   87.920000     150.000000
# std      6.705840       40.079563   11.495255    6.705840      24.225105
#
#         CD - TS %  ...  Rolling_Avg_VS_7D  Hydrolyser Temp - Avg  \
# count  646.000000  ...         640.000000             583.000000
# mean    26.829257  ...         101.310938              48.701383
# min     14.400000  ...           1.137021               0.000000
# 25%     22.100000  ...          46.333536              51.580000
# 50%     24.800000  ...         110.949486              54.180000
# 75%     30.875000  ...         146.374056              55.660000
# max     48.500000  ...         195.203974              61.190000
# std      6.548751  ...          57.429971              16.033923
#
#        Digester Temp - Avg         HRT           VFA         OLR  \
# count           585.000000  646.000000    316.000000  646.000000
# mean             52.661746    5.297353   2647.889873   19.713804
# min               0.000000    0.420000    478.300000   10.000000
# 25%              49.045000    2.842500    777.100000   14.970579
# 50%              51.740000    4.620000    921.700000   17.000000
# 75%              52.660000    7.537500   5149.350000   21.000000
# max            1377.777500   12.810000  14206.200000   94.000000
# std              55.156886    2.869057   2850.174110    9.756172
#
#        Raw biogas production (Nm³/day)  Slurry fed into the digester (Nm3)  \
# count                       646.000000                          645.000000
# mean                      19249.809752                         1300.896775
# min                           0.000000                          120.000000
# 25%                       10139.250000                          741.000000
# 50%                       21329.500000                         1050.000000
# 75%                       26135.500000                         1849.000000
# max                       39690.000000                         2820.000000
# std                        9262.514802                          657.215229
#
#        Slurry fed out of the digester (Nm3)  CBG Production (kg/day)
# count                            541.000000               646.000000
# mean                             820.764695                 7.826280
# min                                9.000000                 0.633000
# 25%                              611.000000                 4.365500
# 50%                              832.000000                 7.815000
# 75%                             1048.000000                10.617250
# max                             1393.000000                16.282000
# std                              284.549642                 3.990153
#
# [8 rows x 27 columns]

# %%
input_data_2 = input_data

# %%
cols_to_ffill = [
    "Feed_TPD_Lag_1",
    "Feed_TPD_Lag_3",
    "Feed_TPD_Lag_7",
    "Rolling_Avg_Feed_7D",
    "Rolling_Avg_VS_7D"
]

input_data_2[cols_to_ffill] = input_data_2[cols_to_ffill].ffill().bfill()

# %%
input_data_2["Slurry fed out of the digester (Nm3)"] = (
    input_data_2["Slurry fed out of the digester (Nm3)"]
    .replace(0, np.nan)
    .fillna(input_data_2["Slurry fed into the digester (Nm3)"].shift(1))
)

# %%
input_data_2["VFA"] = input_data_2["VFA"].replace(0, np.nan)
input_data_2["VFA"] = input_data_2["VFA"].ffill().bfill()

# %%
cols = [
    "Hydrolyser Temp - Avg",
    "Digester Temp - Avg",
    "Slurry fed into the digester (Nm3)"
]

input_data_2[cols] = input_data_2[cols].replace(0, np.nan)
input_data_2[cols] = input_data_2[cols].fillna(df[cols].mean())

# %%
input_data_2.isna().sum()
# Out:
# Serial Number                           0
# Date                                    0
# Feed TPD - PS                           0
# PS - TS %                               0
# PS - VS %                               0
# Feed TPD - PMC                          0
# PMC - TS %                              0
# PMC - VS %                              0
# Feed TPD - CD                           0
# CD - TS %                               0
# CD - VS %                               0
# Total_Feed_TPD                          0
# Total_VS_TPD                            0
# Feed_TPD_Lag_1                          0
# Feed_TPD_Lag_3                          0
# Feed_TPD_Lag_7                          0
# Rolling_Avg_Feed_7D                     0
# Rolling_Avg_VS_7D                       0
# Hydrolyser Temp - Avg                   0
# Digester Temp - Avg                     0
# HRT                                     0
# VFA                                     0
# OLR                                     0
# Raw biogas production (Nm³/day)         0
# Slurry fed into the digester (Nm3)      0
# Slurry fed out of the digester (Nm3)    0
# CBG Production (kg/day)                 0
# dtype: int64

# %%
A = input_data_2.drop(columns=["Serial Number", "Date"])
TARGET = "CBG Production (kg/day)"

# %%
X = A.drop(columns=[TARGET])
y = input_data_2[TARGET]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

split_index = int(len(input_data) * 0.8)

X_train = X.iloc[:split_index]
X_test  = X.iloc[split_index:]

y_train = y.iloc[:split_index]
y_test  = y.iloc[split_index:]

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.2),

    Dense(32, activation="relu"),
    Dropout(0.2),

    Dense(1)  # Output: CBG (kg/day)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001,
    ),
    loss="mse"
)

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True
)

history = model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.2,   # only from TRAIN
    epochs=300,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 32.3904 - val_loss: 77.3022
# Epoch 2/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 17.5455 - val_loss: 21.5291
# Epoch 3/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.3886 - val_loss: 3.9457
# Epoch 4/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7407 - val_loss: 4.9868
# Epoch 5/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8631 - val_loss: 5.2908
# Epoch 6/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9711 - val_loss: 5.3207
# Epoch 7/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6061 - val_loss: 5.2213
# Epoch 8/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5205 - val_loss: 5.7639
# Epoch 9/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5392 - val_loss: 4.8945
# Epoch 10/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0025 - val_loss: 4.3627
# Epoch 11/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8878 - val_loss: 6.2576
# Epoch 12/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3596 - val_loss: 4.7390
# Epoch 13/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8195 - val_loss: 4.8053
# Epoch 14/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7509 - val_loss: 5.8305
# Epoch 15/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0136 - val_loss: 5.2569
# Epoch 16/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6612 - val_loss: 4.9933
# Epoch 17/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6125 - val_loss: 5.6171
# Epoch 18/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8905 - val_loss: 4.2946
# Epoch 19/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6823 - val_loss: 5.2263
# Epoch 20/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7156 - val_loss: 5.0460
# Epoch 21/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4039 - val_loss: 5.0505
# Epoch 22/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8688 - val_loss: 3.6851
# Epoch 23/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5571 - val_loss: 4.9204
# Epoch 24/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5932 - val_loss: 4.0083
# Epoch 25/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4523 - val_loss: 3.7578
# Epoch 26/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3392 - val_loss: 4.8671
# Epoch 27/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3489 - val_loss: 4.6705
# Epoch 28/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4881 - val_loss: 3.5137
# Epoch 29/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4107 - val_loss: 3.9388
# Epoch 30/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3504 - val_loss: 3.5762
# Epoch 31/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6274 - val_loss: 4.2366
# Epoch 32/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1875 - val_loss: 3.9894
# Epoch 33/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5048 - val_loss: 4.1861
# Epoch 34/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0889 - val_loss: 4.4493
# Epoch 35/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2966 - val_loss: 4.6249
# Epoch 36/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2917 - val_loss: 3.6168
# Epoch 37/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1809 - val_loss: 3.2050
# Epoch 38/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1628 - val_loss: 5.8772
# Epoch 39/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2984 - val_loss: 2.7262
# Epoch 40/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9285 - val_loss: 3.0817
# Epoch 41/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1425 - val_loss: 3.6583
# Epoch 42/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5315 - val_loss: 3.3563
# Epoch 43/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2459 - val_loss: 4.3296
# Epoch 44/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4852 - val_loss: 2.8637
# Epoch 45/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0177 - val_loss: 5.5228
# Epoch 46/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9945 - val_loss: 3.7449
# Epoch 47/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2644 - val_loss: 2.5939
# Epoch 48/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2247 - val_loss: 4.2785
# Epoch 49/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2832 - val_loss: 3.5867
# Epoch 50/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0267 - val_loss: 2.9018
# Epoch 51/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8647 - val_loss: 4.4232
# Epoch 52/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0570 - val_loss: 3.7643
# Epoch 53/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0028 - val_loss: 2.7613
# Epoch 54/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9424 - val_loss: 3.8862
# Epoch 55/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2034 - val_loss: 3.9415
# Epoch 56/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8913 - val_loss: 2.6634
# Epoch 57/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7871 - val_loss: 2.9605
# Epoch 58/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0924 - val_loss: 3.3480
# Epoch 59/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0179 - val_loss: 3.1238
# Epoch 60/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0578 - val_loss: 2.9811
# Epoch 61/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2790 - val_loss: 2.5985
# Epoch 62/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0141 - val_loss: 3.8141
# Epoch 63/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1809 - val_loss: 3.3155
# Epoch 64/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9557 - val_loss: 2.9133
# Epoch 65/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9847 - val_loss: 2.9148
# Epoch 66/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9553 - val_loss: 2.6901
# Epoch 67/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1702 - val_loss: 2.5189
# Epoch 68/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9204 - val_loss: 2.3534
# Epoch 69/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9418 - val_loss: 2.6657
# Epoch 70/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9702 - val_loss: 3.4132
# Epoch 71/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0165 - val_loss: 2.0308
# Epoch 72/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8037 - val_loss: 2.5553
# Epoch 73/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0800 - val_loss: 3.5160
# Epoch 74/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1869 - val_loss: 3.2011
# Epoch 75/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9776 - val_loss: 2.5874
# Epoch 76/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8408 - val_loss: 1.7714
# Epoch 77/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8750 - val_loss: 3.3273
# Epoch 78/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8773 - val_loss: 3.1631
# Epoch 79/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6525 - val_loss: 2.9218
# Epoch 80/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9486 - val_loss: 2.7527
# Epoch 81/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9703 - val_loss: 2.4041
# Epoch 82/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9385 - val_loss: 1.8957
# Epoch 83/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0639 - val_loss: 2.9135
# Epoch 84/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9402 - val_loss: 3.2578
# Epoch 85/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7575 - val_loss: 2.3426
# Epoch 86/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7770 - val_loss: 2.1947
# Epoch 87/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1989 - val_loss: 2.4200
# Epoch 88/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8950 - val_loss: 2.1634
# Epoch 89/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7155 - val_loss: 2.1530
# Epoch 90/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7060 - val_loss: 2.1475
# Epoch 91/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7132 - val_loss: 1.8424
# Epoch 92/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9103 - val_loss: 3.0808
# Epoch 93/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8095 - val_loss: 2.0379
# Epoch 94/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8882 - val_loss: 1.7526
# Epoch 95/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9124 - val_loss: 2.7378
# Epoch 96/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8080 - val_loss: 1.6100
# Epoch 97/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8134 - val_loss: 2.5985
# Epoch 98/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8307 - val_loss: 2.7223
# Epoch 99/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9027 - val_loss: 2.1051
# Epoch 100/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9953 - val_loss: 3.1206
# Epoch 101/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0731 - val_loss: 2.1163
# Epoch 102/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7894 - val_loss: 1.9806
# Epoch 103/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8136 - val_loss: 2.6117
# Epoch 104/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8156 - val_loss: 2.4776
# Epoch 105/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6789 - val_loss: 2.1854
# Epoch 106/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7994 - val_loss: 2.1469
# Epoch 107/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8008 - val_loss: 2.7661
# Epoch 108/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9595 - val_loss: 1.7131
# Epoch 109/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7287 - val_loss: 2.0207
# Epoch 110/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7470 - val_loss: 2.6002
# Epoch 111/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8447 - val_loss: 1.7532
# Epoch 112/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7394 - val_loss: 2.5876
# Epoch 113/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8901 - val_loss: 2.1201
# Epoch 114/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7552 - val_loss: 1.9329
# Epoch 115/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7158 - val_loss: 2.1489
# Epoch 116/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7887 - val_loss: 2.5108

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(X_test_scaled).flatten()

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("ANN Model Performance")
print("---------------------")
print(f"RMSE : {rmse:.2f} kg/day")
print(f"R²   : {r2:.3f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ANN Model Performance
# ---------------------
# RMSE : 1.15 kg/day
# R²   : 0.656

# %%
# assuming df is your original dataframe
# and y_test came from train_test_split

test_dates = input_data.loc[y_test.index, "Date"]

plt.figure(figsize=(12,5))
plt.plot(test_dates, y_test, label="Actual CBG", marker="o")
plt.plot(test_dates, y_pred, label="Predicted CBG", marker="x")

plt.xlabel("Date")
plt.ylabel("CBG Production")
plt.title("Actual vs Predicted CBG over Time")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print("Model input shape:", model.input_shape)
# Out:
# Model input shape: (None, 24)

# %%
N_DAYS = 7

FEATURE_COLS = [
    # Feed & composition
    "Feed TPD - PS",
    "PS - TS %",
    "PS - VS %",
    "Feed TPD - PMC",
    "PMC - TS %",
    "PMC - VS %",
    "Feed TPD - CD",
    "CD - TS %",
    "CD - VS %",

    # Totals
    "Total_Feed_TPD",
    "Total_VS_TPD",

    # Lag features (calculated)
    "Feed_TPD_Lag_1",
    "Feed_TPD_Lag_3",
    "Feed_TPD_Lag_7",

    # Rolling features (calculated)
    "Rolling_Avg_Feed_7D",
    "Rolling_Avg_VS_7D",

    # Process parameters
    "Hydrolyser Temp - Avg",
    "Digester Temp - Avg",
    "HRT",
    "VFA",
    "OLR",

    # NEW FEATURES
    "Raw biogas production (Nm³/day)",
    "Slurry fed into the digester (Nm3)",
    "Slurry fed out of the digester (Nm3)",
]

input_data = input_data.fillna(method="ffill")
input_data = input_data.fillna(method="bfill")

df = input_data.sort_values("Date").reset_index(drop=True)

last_date = pd.to_datetime(df.iloc[-1]["Date"])

# Feed & VS history (used for lag + rolling)
feed_history = list(df["Total_Feed_TPD"].tail(7))
vs_history = list(df["Total_VS_TPD"].tail(7))



future_rows = []

for day in range(1, N_DAYS + 1):

    future_date = last_date + timedelta(days=day)

    row = {}

    # ----------------------------
    # 1. Stable features (copied)
    # ----------------------------
    for col in FEATURE_COLS:
        if col not in [
            "Feed_TPD_Lag_1",
            "Feed_TPD_Lag_3",
            "Feed_TPD_Lag_7",
            "Rolling_Avg_Feed_7D",
            "Rolling_Avg_VS_7D",
        ]:
            row[col] = df.iloc[-1][col]

    # ----------------------------
    # 2. Lag features (calculated)
    # ----------------------------
    row["Feed_TPD_Lag_1"] = feed_history[-1]
    row["Feed_TPD_Lag_3"] = np.mean(feed_history[-3:])
    row["Feed_TPD_Lag_7"] = np.mean(feed_history[-7:])

    # ----------------------------
    # 3. Rolling averages
    # ----------------------------
    row["Rolling_Avg_Feed_7D"] = np.mean(feed_history)
    row["Rolling_Avg_VS_7D"] = np.mean(vs_history)

    # ----------------------------
    # 4. Create dataframe for ANN
    # ----------------------------
    X_future = pd.DataFrame([row])[FEATURE_COLS]
    X_future = X_future.astype(float)

    # Scale
    X_future_scaled = scaler.transform(X_future)
    X_future_scaled = np.array(X_future_scaled, dtype=np.float32)

    # ----------------------------
    # 5. Predict CBG
    # ----------------------------
    cbg_pred = model.predict(X_future_scaled, verbose=0)[0][0]

    # ----------------------------
    # 6. Store result
    # ----------------------------
    row["Date"] = future_date
    row["Predicted_CBG_kg_day"] = cbg_pred

    future_rows.append(row)

    # ----------------------------
    # 7. Update buffers (recursive!)
    # ----------------------------
    feed_history.append(row["Total_Feed_TPD"])
    vs_history.append(row["Total_VS_TPD"])

    feed_history = feed_history[-7:]
    vs_history = vs_history[-7:]

forecast_df = pd.DataFrame(future_rows)

forecast_df["Cumulative_CBG_kg"] = forecast_df["Predicted_CBG_kg_day"].cumsum()
forecast_df["CBG_kg_per_Ton_VS"] = (
    forecast_df["Predicted_CBG_kg_day"] / forecast_df["Total_VS_TPD"]
)

print(
    forecast_df[
        ["Date", "Predicted_CBG_kg_day"]
    ]
)
# Out:
# /tmp/ipython-input-2900/2861099560.py:41: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   input_data = input_data.fillna(method="ffill")
# /tmp/ipython-input-2900/2861099560.py:42: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   input_data = input_data.fillna(method="bfill")
#         Date  Predicted_CBG_kg_day
# 0 2036-10-08             15.178605
# 1 2036-10-09             15.247979
# 2 2036-10-10             15.362676
# 3 2036-10-11             15.492928
# 4 2036-10-12             15.596431
# 5 2036-10-13             15.680271
# 6 2036-10-14             15.856233

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure datetime
df["Date"] = pd.to_datetime(df["Date"])
forecast_df["Date"] = pd.to_datetime(forecast_df["Date"])

TARGET_COL = "CBG Production (kg/day)"  # change if your actual column name differs

# Last 7 actual days
last_7_actual = input_data.tail(7)[["Date", TARGET_COL]].copy()

# Last 7 predicted (aligning with last 7 rows)
last_7_pred = pd.DataFrame({
    "Date": last_7_actual["Date"].values,
    "Predicted_CBG": y_pred_inv[-7:].flatten()
})

next_7_forecast = forecast_df.head(7)[
    ["Date", "Predicted_CBG_kg_day"]
].rename(columns={"Predicted_CBG_kg_day": "Forecasted_CBG"})


plt.figure()

# Actual CBG (last 7 days)
plt.plot(
    last_7_actual["Date"],
    last_7_actual[TARGET_COL],
    marker="o",
    label="Actual CBG (Last 7 Days)"
)

# Predicted CBG (last 7 days)
plt.plot(
    last_7_pred["Date"],
    last_7_pred["Predicted_CBG"],
    marker="s",
    linestyle="--",
    label="Predicted CBG (Last 7 Days)"
)

# Forecasted CBG (next 7 days)
plt.plot(
    next_7_forecast["Date"],
    next_7_forecast["Forecasted_CBG"],
    marker="^",
    linestyle=":",
    label="Forecasted CBG (Next 7 Days)"
)

# Vertical line to separate history & forecast
plt.axvline(
    x=last_7_actual["Date"].iloc[-1],
    linestyle="dashdot",
    label="Forecast Start"
)

plt.xlabel("Date")
plt.ylabel("CBG (kg/day)")
plt.title("CBG Production: Actual vs Predicted vs Forecast")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#prophet to be checked
